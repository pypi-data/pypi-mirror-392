# %% [markdown]
# # Test

# %%
# !conda list qsimkit
# Out:
# # packages in environment at /opt/homebrew/Caskroom/miniforge/base:
# #
# # Name                     Version                           Build            Channel
# qsimkit                    0.1.15.dev0+g656aa07c5.d20251116  pypi_0           pypi

# %%
import sys
sys.path.append('../')
from qsimkit import spin

H = spin.Nearest_Neighbour_1d(4)
H.ham
# H.ham_xyz
# Out:
# SparsePauliOp(['IIII'],
#               coeffs=[0.+0.j])
