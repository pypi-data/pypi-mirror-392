# %% [markdown]
# ## HCP analyis
# This analysis is meant to check and tell that actually InstaNovo predict well the True Positives, unfortunately part of FP we find upon the confidence threshold we setted, are peptides that belong to E.coli so, somehow, still contaminations. This analysis wants to show the percentages of these FP that matches with E.coli.
