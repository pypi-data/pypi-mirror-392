# %% [markdown]
# # MesoMath Notebooks
#
# * [Interactive Babylonian calculator](babcalc.ipynb)
# * [BabN class tutorial](BabN.ipynb)
# * [Metrological classes tutorial](Metrology.ipynb)
#
# > Please, note that all this stuff is still in an experimental stage!
