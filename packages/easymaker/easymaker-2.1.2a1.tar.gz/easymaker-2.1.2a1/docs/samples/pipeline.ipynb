# %% [markdown]
# # NHN AI EasyMaker SDK 사용 예제
#
# 이 노트북에서는 NHN AI EasyMaker SDK를 사용하여 파이프라인을 생성하고 관리하는 방법을 보여줍니다.

# %%
# 필요한 라이브러리 임포트
import easymaker

# %%
# 필요한 변수 설정
region="kr1"
appkey="YOUR_APP_KEY"

# 인증 토큰 발급 가이드 : https://docs.nhncloud.com/ko/nhncloud/ko/public-api/api-authentication/#_1
user_access_key_id="YOUR_ACCESS_KEY_ID"
secret_access_key="YOUR_SECRET_ACCESS_KEY"
access_token=easymaker.sample.get_access_token(user_access_key_id, secret_access_key),

# 파이프라인 파일 경로
pipeline_spec_manifest_path="./sample-pipeline.yaml"

# %% [markdown]
# ## SDK 초기화
#
# SDK를 사용하기 위해 초기화합니다.

# %%
# SDK 초기화
easymaker.init(
    region=region,
    appkey=appkey,
    access_token=access_token,
)

# %% [markdown]
# ## 파이프라인 업로드
#
# 파이프라인을 업로드합니다.

# %%
# 파이프라인 업로드
pipeline = easymaker.Pipeline().upload(
    pipeline_name="pipeline_sample",
    pipeline_spec_manifest_path=pipeline_spec_manifest_path,
)
pipeline.print_info()
# Out:
# [AI EasyMaker] Pipeline upload request complete. Pipeline ID : gzxw0pgevx6c
# [AI EasyMaker] Pipeline upload status: CREATE_REQUESTED (0:00:00) Please wait...
# [AI EasyMaker] Pipeline upload status: CREATE_IN_PROGRESS (0:00:10) Please wait...
# [AI EasyMaker] Pipeline upload status: CREATE_IN_PROGRESS (0:00:20) Please wait...
# [AI EasyMaker] Pipeline upload status: CREATE_IN_PROGRESS (0:00:30) Please wait...
# [AI EasyMaker] Pipeline upload complete. pipeline_id: gzxw0pgevx6c
# {
#     "appKey": "qV5VIb2S1hr33zTS",
#     "createdDatetime": "2025-06-02T11:35:05+09:00",
#     "pipelineId": "gzxw0pgevx6c",
#     "pipelineName": "pipeline_sample",
#     "pipelineParameterSpecList": [
#         {
#             "parameterName": "experiment_name",
#             "parameterType": "STRING",
#             "isOptional": true,
#             "defaultValue": "wf_test_experiment"
#         },
#         {
#             "parameterName": "parameter_bool",
#             "parameterType": "BOOLEAN",
#             "isOptional": true,
#             "defaultValue": "true"
#         },
#         {
#             "parameterName": "parameter_float",
#             "parameterType": "NUMBER_DOUBLE",
#             "isOptional": true,
#             "defaultValue": "1"
#         },
#         {
#             "parameterName": "parameter_int",
#             "parameterType": "NUMBER_INTEGER",
#             "isOptional": true,
#             "defaultValue": "1"
#         },
#         {
#             "parameterName": "parameter_list",
#             "parameterType": "LIST",
#             "isOptional": true,
#             "defaultValue": "[\"a\",\"b\",\"c\"]"
#         },
#         {
#             "parameterName": "parameter_struct",
#             "parameterType": "STRUCT",
#             "isOptional": true,
#             "defaultValue": "{\"a\":1,\"b\":2,\"c\":3}"
#         },
#         {
#             "parameterName": "training_name",
#             "parameterType": "STRING",
#             "isOptional": true,
#             "defaultValue": "wf_test_training"
#         }
#     ],
#     "pipelineStatusCode": "ACTIVE"
# }

# %% [markdown]
# ## 파이프라인 실행
#
# 업로드된 파이프라인을 실행합니다.

# %%
# 실험 생성
experiment = easymaker.Experiment().create(experiment_name="pipeline_experiment_sample")
experiment.print_info()

# %%
# 인스턴스 목록 조회
instance_type_list = easymaker.PipelineRun.get_instance_type_list()
for instance in instance_type_list:
    instance.print_info()
instance_type_name = instance_type_list[0].name
# Out:
# {
#     "id": "35a73b57-58a7-434d-aa08-5249aaa95b3e",
#     "name": "m2.c2m4",
#     "vcpus": 2,
#     "ram": 4096,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "edc79d63-98c3-4b77-a2d4-482d70e6b554",
#     "name": "m2.c4m8",
#     "vcpus": 4,
#     "ram": 8192,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "eaddf5bd-2725-409a-ac57-044935747183",
#     "name": "m2.c8m16",
#     "vcpus": 8,
#     "ram": 16384,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "5b45e38f-8d54-4a8b-82e8-a104e13d464e",
#     "name": "m2.c16m32",
#     "vcpus": 16,
#     "ram": 32768,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "f5ebd3a7-f978-477d-8dcf-2a1578e29df3",
#     "name": "c2.c2m2",
#     "vcpus": 2,
#     "ram": 2048,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "57865308-7e1f-4931-aaea-1c36eb053900",
#     "name": "c2.c4m4",
#     "vcpus": 4,
#     "ram": 4096,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "c8f6212c-c259-414c-a6bd-118eb3bb6693",
#     "name": "c2.c8m8",
#     "vcpus": 8,
#     "ram": 8192,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "94180d79-bfa4-40a4-91ef-7ef08ce15bd3",
#     "name": "c2.c16m16",
#     "vcpus": 16,
#     "ram": 16384,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "db51400e-85a1-4d65-930a-52d1d40941a9",
#     "name": "r2.c2m8",
#     "vcpus": 2,
#     "ram": 8192,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "8339613a-2837-4c72-906b-a8a47aa17c3f",
#     "name": "r2.c4m16",
#     "vcpus": 4,
#     "ram": 16384,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "b8aa863d-598a-457e-9804-f09d1593ac4c",
#     "name": "r2.c8m32",
#     "vcpus": 8,
#     "ram": 32768,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "97d88b3b-af44-4fc5-82ac-8847d1a0dc15",
#     "name": "r2.c8m64",
#     "vcpus": 8,
#     "ram": 65536,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "55b679a3-cac9-48ff-afbe-c6a32ef155bc",
#     "name": "x1.c16m64",
#     "vcpus": 16,
#     "ram": 65536,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "6ab714c1-26c6-4b39-ba37-53a8f6c83f86",
#     "name": "x1.c16m128",
#     "vcpus": 16,
#     "ram": 131072,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "31fa632d-aeec-4f12-8a57-ce9d146228e5",
#     "name": "x1.c32m128",
#     "vcpus": 32,
#     "ram": 131072,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "97604802-a090-43fa-a5ce-c7cfd737fbba",
#     "name": "x1.c32m256",
#     "vcpus": 32,
#     "ram": 262144,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "acf2213f-6007-4d0c-807c-ec9ea1d05130",
#     "name": "x1.c64m256",
#     "vcpus": 64,
#     "ram": 262144,
#     "disk": 0,
#     "gpu": false
# }
# {
#     "id": "b734bc0a-8f62-4af2-821d-e6adc691b0b1",
#     "name": "g2.t4.c4m32",
#     "vcpus": 4,
#     "ram": 32768,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 1,
#     "gpuMemory": 16
# }
# {
#     "id": "e383b9f4-046d-434f-b155-deaf7815f709",
#     "name": "g2.t4.c8m64",
#     "vcpus": 8,
#     "ram": 65536,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 2,
#     "gpuMemory": 32
# }
# {
#     "id": "ce521ccf-e12d-4cfe-80bf-78c0fee3c8d4",
#     "name": "g2.t4.c16m128",
#     "vcpus": 16,
#     "ram": 131072,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 4,
#     "gpuMemory": 64
# }
# {
#     "id": "4d9632bd-9deb-42c5-96b1-d7ac40f39f0f",
#     "name": "g2.t4.c32m256",
#     "vcpus": 32,
#     "ram": 262144,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 8,
#     "gpuMemory": 128
# }
# {
#     "id": "72dc678f-59a0-4f19-9599-f0aa28e735f7",
#     "name": "g2.v100.c8m90",
#     "vcpus": 8,
#     "ram": 92160,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 1,
#     "gpuMemory": 32
# }
# {
#     "id": "d1290876-732f-40f6-84fb-b14be3d83281",
#     "name": "g2.v100.c16m180",
#     "vcpus": 16,
#     "ram": 184320,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 2,
#     "gpuMemory": 64
# }
# {
#     "id": "0dc63e3d-3e92-4164-9bfe-447dd60a5b5c",
#     "name": "g2.v100.c32m360",
#     "vcpus": 32,
#     "ram": 368640,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 4,
#     "gpuMemory": 128
# }
# {
#     "id": "261780ac-06b2-4a19-b5e9-2be78f2216b2",
#     "name": "g2.v100.c64m720",
#     "vcpus": 64,
#     "ram": 737280,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 8,
#     "gpuMemory": 256
# }
# {
#     "id": "ad3288e4-6ad4-458f-869e-c030de4e2bf2",
#     "name": "g4.c12m225",
#     "vcpus": 12,
#     "ram": 230400,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 1,
#     "gpuMemory": 40
# }
# {
#     "id": "96f80d2c-9150-43c2-8920-714e93c7e4b7",
#     "name": "g4.c92m1800",
#     "vcpus": 92,
#     "ram": 1843200,
#     "disk": 0,
#     "gpu": true,
#     "gpuCount": 8,
#     "gpuMemory": 320
# }

# %%
# 파이프라인 실행
pipeline_run = easymaker.PipelineRun().create(
    pipeline_run_name="pipeline_run_sample",
    pipeline_id=pipeline.pipeline_id,
    experiment_id=experiment.experiment_id,
    instance_type_name=instance_type_name,
    instance_count=1,
    boot_storage_size=50,
    parameter_list=[
        easymaker.Parameter(parameter_name="experiment_name", parameter_value="pipeline_experiment"),
    ],
)
pipeline_run.print_info()
# Out:
# [AI EasyMaker] Pipeline run create request complete. pipeline_run_id: a3slr3tjdj59
# [AI EasyMaker] PipelineRun create status: CREATE_REQUESTED (0:00:00) Please wait...
# [AI EasyMaker] PipelineRun create status: CREATE_IN_PROGRESS (0:00:10) Please wait...
# [AI EasyMaker] PipelineRun create status: CREATE_IN_PROGRESS (0:00:20) Please wait...
# [AI EasyMaker] PipelineRun create status: CREATE_IN_PROGRESS (0:09:30) Please wait...
# [AI EasyMaker] PipelineRun create status: CREATE_IN_PROGRESS (0:09:40) Please wait...
# [AI EasyMaker] PipelineRun create status: RUNNING (0:09:50) Please wait...
# [AI EasyMaker] PipelineRun create status: RUNNING (0:10:00) Please wait...
# [AI EasyMaker] PipelineRun create status: RUNNING (0:14:40) Please wait...
# [AI EasyMaker] PipelineRun create status: RUNNING (0:14:50) Please wait...
# [AI EasyMaker] PipelineRun create status: COMPLETE_IN_PROGRESS (0:15:00) Please wait...
# [AI EasyMaker] PipelineRun create status: COMPLETE_IN_PROGRESS (0:15:10) Please wait...
# [AI EasyMaker] PipelineRun create status: COMPLETE_IN_PROGRESS (0:15:40) Please wait...
# [AI EasyMaker] PipelineRun create status: COMPLETE_IN_PROGRESS (0:15:50) Please wait...
# [AI EasyMaker] PipelineRun create complete. pipeline_run_id: a3slr3tjdj59
# {
#     "appKey": "qV5VIb2S1hr33zTS",
#     "createdDatetime": "2025-06-02T11:40:51+09:00",
#     "pipelineRunId": "a3slr3tjdj59",
#     "pipelineRunName": "pipeline_run_sample",
#     "pipelineRunStatusCode": "COMPLETE",
#     "pipeline": {
#         "appKey": "qV5VIb2S1hr33zTS",
#         "createdDatetime": "2025-06-02T11:35:05+09:00",
#         "pipelineId": "gzxw0pgevx6c",
#         "pipelineName": "pipeline_sample",
#         "pipelineStatusCode": "ACTIVE"
#     },
#     "experiment": {
#         "appKey": "qV5VIb2S1hr33zTS",
#         "createdDatetime": "2025-06-02T11:36:40+09:00",
#         "experimentId": "eq6ed8l6dpx6",
#         "experimentName": "pipeline_experiment_sample",
#         "experimentStatusCode": "ACTIVE"
#     },
#     "instanceType": {
#         "id": "35a73b57-58a7-434d-aa08-5249aaa95b3e",
#         "name": "m2.c2m4",
#         "vcpus": 2,
#         "ram": 4096,
#         "disk": 0,
#         "gpu": false
#     },
#     "instanceCount": 1,
#     "bootStorage": {
#         "storageSize": 50
#     },
#     "elapsedTimeSeconds": 947,
#     "startedDatetime": "2025-06-02T11:40:50+09:00",
#     "finishedDatetime": "2025-06-02T11:56:37+09:00",
#     "nasList": [],
#     "parameterList": [
#         {
#             "parameterName": "experiment_name",
#             "parameterValue": "pipeline_experiment_sample"
#         }
#     ]
# }

# %% [markdown]
# ## 파이프라인 실행 중지
#
# 실행 중인 파이프라인을 중지합니다.

# %%
# 파이프라인 실행 중지
#pipeline_run.stop()

# %% [markdown]
# ## 파이프라인 실행 삭제
#
# 생성된 파이프라인 실행을 삭제합니다.

# %%
# 파이프라인 삭제
pipeline_run.delete()
