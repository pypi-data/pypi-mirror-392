# %% [markdown]
# # Operator/Benchmark Sweep
#
# Run the benchmark suite with multiple operator presets and compare objective/runtime metrics.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
while PROJECT_ROOT != PROJECT_ROOT.parent and not (PROJECT_ROOT / "pyproject.toml").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / "pyproject.toml").exists():
    raise RuntimeError(
        "Notebook must be executed within a FHOPS checkout (pyproject.toml not found)."
    )
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))


from fhops.cli.benchmarks import run_benchmark_suite

BENCH_DIR = PROJECT_ROOT / "docs/examples/analytics/data/operator_sweep"
summary = run_benchmark_suite(
    [PROJECT_ROOT / "examples/synthetic/medium/scenario.yaml"],
    BENCH_DIR,
    time_limit=5,
    sa_iters=150,
    include_mip=False,
    preset_comparisons=["explore", "stabilise"],
)
summary
# Out:
#                          FHOPS Benchmark Summary
# ┏━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ scenario ┃ solver ┃ preset_label ┃ objective ┃ runtime_s ┃ assignments ┃
# ┡━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ user-1   │ sa     │ default      │ 89.370    │ 0.04      │ 9           │
# │ user-1   │ sa     │ explore      │ 94.371    │ 0.09      │ 9           │
# │ user-1   │ sa     │ stabilise    │ 94.908    │ 0.08      │ 9           │
# └──────────┴────────┴──────────────┴───────────┴───────────┴─────────────┘
#   scenario                                      scenario_path solver  \
# 0   user-1  /home/gep/projects/fhops/examples/synthetic/me...     sa
# 1   user-1  /home/gep/projects/fhops/examples/synthetic/me...     sa
# 2   user-1  /home/gep/projects/fhops/examples/synthetic/me...     sa
#
#    objective  runtime_s  assignments  kpi_total_production  \
# 0     89.370   0.043104            9                89.370
# 1     94.371   0.093004            9                94.371
# 2     94.908   0.075353            9                94.908
#
#    kpi_completed_blocks  kpi_utilisation_ratio_mean_shift  \
# 0                   5.0                               1.0
# 1                   5.0                               1.0
# 2                   6.0                               1.0
#
#    kpi_utilisation_ratio_weighted_shift  ...  \
# 0                                   1.0  ...
# 1                                   1.0  ...
# 2                                   1.0  ...
#
#                                      operators_stats scenario_key  \
# 0  {"move": {"acceptance_rate": 1.0, "accepted": ...       user-1
# 1  {"block_insertion": {"acceptance_rate": 1.0, "...       user-1
# 2  {"block_insertion": {"acceptance_rate": 1.0, "...       user-1
#
#    objective_vs_mip_gap  objective_vs_mip_ratio  solver_category  \
# 0                  <NA>                    <NA>        heuristic
# 1                  <NA>                    <NA>        heuristic
# 2                  <NA>                    <NA>        heuristic
#
#   best_heuristic_solver  best_heuristic_objective  best_heuristic_runtime_s  \
# 0                    sa                     89.37                  0.043104
# 1                    sa                     89.37                  0.043104
# 2                    sa                     89.37                  0.043104
#
#    objective_gap_vs_best_heuristic  runtime_ratio_vs_best_heuristic
# 0                            0.000                         1.000000
# 1                            5.001                         2.157648
# 2                            5.538                         1.748160
#
# [3 rows x 35 columns]

# %% [markdown]
# ## Objective Comparison

# %%
objective_pivot = summary.pivot_table(index="preset_label", values="objective")
objective_pivot
# Out:
#               objective
# preset_label
# default          89.370
# explore          94.371
# stabilise        94.908

# %% [markdown]
# ## Runtime Comparison

# %%
runtime_pivot = summary.pivot_table(index="preset_label", values="runtime_s")
runtime_pivot
# Out:
#               runtime_s
# preset_label
# default        0.043104
# explore        0.093004
# stabilise      0.075353
