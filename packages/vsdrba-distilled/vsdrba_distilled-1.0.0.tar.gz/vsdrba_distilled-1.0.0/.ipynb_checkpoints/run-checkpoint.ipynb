# %%
# !git clone https://github.com/routineLife1/VS-DistilDRBA.git
# %cd VS-DistilDRBA

# %%
# %load_ext yuuno
# Out:
# /usr/local/lib/python3.10/dist-packages/yuuno/autodiscover.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
# %%vspipe --y4m | ffmpeg -r 24000/1001*2 -y -i "video/test.mp4" -i - -map 0:a -map 1:v -vcodec hevc_nvenc -c:a copy -qp 16 -preset 18 -profile:v 1 out_2x.mkv
# from vsdrba_distilled import drba_distilled
# import vapoursynth as vs
# from vapoursynth import core
# clip = core.bs.VideoSource(source="video/test.mp4")
# clip = core.resize.Bicubic(clip=clip, matrix_in_s="709", format=vs.RGBH,width=1920, height=1080)
# ret = drba_distilled(clip, trt=True, factor_num=2, factor_den=1, scale=1.0, model="v1", auto_download=True)
# clip = core.resize.Bicubic(clip=ret, matrix_s="709", format=vs.YUV420P16)
# clip.set_output()
# Out:
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu_6]), LayerImpl: PointWiseV2, tactic: 0x0000000000000003
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu_6]), LayerImpl: PointWiseV2, tactic: 0x000000000000000b
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu_6]), LayerImpl: PointWiseV2, tactic: 0x000000000000001d
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu]), LayerImpl: PointWiseV2, tactic: 0x0000000000000003
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu]), LayerImpl: PointWiseV2, tactic: 0x000000000000000b
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu]), LayerImpl: PointWiseV2, tactic: 0x000000000000001d
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu_3]), LayerImpl: PointWiseV2, tactic: 0x0000000000000003
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu_3]), LayerImpl: PointWiseV2, tactic: 0x000000000000000b
# WARNING:torch_tensorrt [TensorRT Conversion Context]:Cache result detected as invalid for node: PWN([LEAKY_RELU]-[aten_ops.leaky_relu.default]-[encode.relu/leaky_relu_3]), LayerImpl: PointWiseV2, tactic: 0x000000000000001d
# EncodeWidget(commandline='ffmpeg -r 24000/1001*2 -y -i "video/test.mp4" -i - -map 0:a -map 1:v -vcodec hevc_nv…
