# %% [markdown]
# # Level 1.0 data from the "Cart_Site" for AOD daily averages
#
# Define a cql2-json filter for:
#
# https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?site=Cart_Site&year=2000&month=6&day=1&year2=2000&month2=6&day2=14&AOD10=1&AVG=20

# %%
from pathlib import Path
from pystac import Item

import json
import sys

out_dir: Path = Path('.')

cql2_filter = {
    "op": "and",
    "args": [
        {"op": "eq", "args": [{"property": "site"}, "Cart_Site"]},
        {"op": "eq", "args": [{"property": "data_type"}, "AOD10"]},
        {"op": "eq", "args": [{"property": "format"}, "csv"]},
        {"op": "eq", "args": [{"property": "data_format"}, "daily-average"]},
        {
            "op": "t_after",
            "args": [
                {"property": "time"},
                {"timestamp": "2000-06-01T00:00:00Z"},
            ],
        },
        {
            "op": "t_before",
            "args": [
                {"property": "time"},
                {"timestamp": "2000-06-14T23:59:59Z"},
            ],
        },
    ],
}

json.dump(cql2_filter, sys.stdout, indent=2)
# Out:
# {
#   "op": "and",
#   "args": [
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "site"
#         },
#         "Cart_Site"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "data_type"
#         },
#         "AOD10"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "format"
#         },
#         "csv"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "data_format"
#         },
#         "daily-average"
#       ]
#     },
#     {
#       "op": "t_after",
#       "args": [
#         {
#           "property": "time"
#         },
#         {
#           "timestamp": "2000-06-01T00:00:00Z"
#         }
#       ]
#     },
#     {
#       "op": "t_before",
#       "args": [
#         {
#           "property": "time"
#         },
#         {
#           "timestamp": "2000-06-14T23:59:59Z"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Execute the `search` operation

# %%
from pygeofilter_aeronet import aeronet_search

item: Item = aeronet_search(
    cql2_filter=cql2_filter,
    output_dir=out_dir
)

json.dump(item.to_dict(), sys.stdout, indent=2)
# Out:
# 2025-11-14 18:03:48.780 | SUCCESS  | pygeofilter_aeronet:aeronet_search:231 - Query on https://aeronet.gsfc.nasa.gov successfully obtained data:
# 2025-11-14 18:03:48.783 | SUCCESS  | pygeofilter_aeronet:aeronet_search:239 - Data saved to to CSV file: /home/stripodi/Documents/pygeofilter/pygeofilter-aeronet/docs/samples/ae1dffb7-7232-4b9c-9835-6c1475edf922.csv
# 2025-11-14 18:03:48.793 | SUCCESS  | pygeofilter_aeronet:aeronet_search:270 - Data saved to GeoParquet file: /home/stripodi/Documents/pygeofilter/pygeofilter-aeronet/docs/samples/ae1dffb7-7232-4b9c-9835-6c1475edf922.parquet
# {
#   "type": "Feature",
#   "stac_version": "1.1.0",
#   "stac_extensions": [],
#   "id": "urn:uuid:ae1dffb7-7232-4b9c-9835-6c1475edf922",
#   "geometry": {
#     "type": "Point",
#     "coordinates": [
#       -97.48639,
#       36.60667
#     ]
#   },
#   "bbox": [
#     -97.48639,
#     36.60667,
#     -97.48639,
#     36.60667
#   ],
#   "properties": {
#     "datetime": "2025-11-14T18:03:48.825092Z"
#   },
#   "links": [
#     {
#       "rel": "related",
#       "href": "https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?site=Cart_Site&AOD10=1&if_no_html=1&AVG=20&year=2000&month=6&day=1&hour=0&year2=2000&month2=6&day2=14&hour2=23",
#       "type": "text/csv",
#       "title": "AERONET Web Service search"
#     }
#   ],
#   "assets": {
#     "csv": {
#       "href": "ae1dffb7-7232-4b9c-9835-6c1475edf922.csv",
#       "type": "text/csv",
#       "description": "Search result - CVS Format"
#     },
#     "geoparquet": {
#       "href": "ae1dffb7-7232-4b9c-9835-6c1475edf922.parquet",
#       "type": "application/vnd.apache.parquet",
#       "description": "Search result - GeoParquet Format"
#     }
#   }
# }

# %% [markdown]
# ## Visualize the results as Data Frame

# %%
from geopandas import read_parquet
from geopandas.geodataframe import GeoDataFrame

geoparquet_file: str = item.get_assets()['geoparquet'].href
geoparquet_data: GeoDataFrame = read_parquet(geoparquet_file)

geoparquet_data
# Out:
#    AERONET_Site Date(dd:mm:yyyy) Time(hh:mm:ss)  Day_of_Year  AOD_1640nm  \
# 0     Cart_Site       31:05:2000       12:00:00          152      -999.0
# 1     Cart_Site       01:06:2000       12:00:00          153      -999.0
# 2     Cart_Site       03:06:2000       12:00:00          155      -999.0
# 3     Cart_Site       04:06:2000       12:00:00          156      -999.0
# 4     Cart_Site       05:06:2000       12:00:00          157      -999.0
# 5     Cart_Site       06:06:2000       12:00:00          158      -999.0
# 6     Cart_Site       07:06:2000       12:00:00          159      -999.0
# 7     Cart_Site       08:06:2000       12:00:00          160      -999.0
# 8     Cart_Site       09:06:2000       12:00:00          161      -999.0
# 9     Cart_Site       11:06:2000       12:00:00          163      -999.0
# 10    Cart_Site       12:06:2000       12:00:00          164      -999.0
# 11    Cart_Site       13:06:2000       12:00:00          165      -999.0
#
#     AOD_1020nm  AOD_870nm  AOD_865nm  AOD_779nm  AOD_675nm  ...  \
# 0     0.035949   0.052400     -999.0     -999.0   0.063064  ...
# 1     0.177293   0.190211     -999.0     -999.0   0.198619  ...
# 2     0.098948   0.113883     -999.0     -999.0   0.134527  ...
# 3     0.113260   0.138564     -999.0     -999.0   0.176712  ...
# 4     0.031582   0.042280     -999.0     -999.0   0.046784  ...
# 5     0.074702   0.098039     -999.0     -999.0   0.125141  ...
# 6     0.065860   0.079687     -999.0     -999.0   0.092880  ...
# 7     0.027215   0.040335     -999.0     -999.0   0.051462  ...
# 8     0.086542   0.117402     -999.0     -999.0   0.166313  ...
# 9     0.027895   0.040069     -999.0     -999.0   0.048234  ...
# 10    0.089634   0.104034     -999.0     -999.0   0.119617  ...
# 11    0.114965   0.128369     -999.0     -999.0   0.136661  ...
#
#     N[340-440_Angstrom_Exponent]  N[440-675_Angstrom_Exponent[Polar]]  \
# 0                             35                                    0
# 1                             31                                    0
# 2                              6                                    0
# 3                              7                                    0
# 4                             55                                    0
# 5                             37                                    0
# 6                             36                                    0
# 7                             39                                    0
# 8                             10                                    0
# 9                              6                                    0
# 10                            22                                    0
# 11                            24                                    0
#
#     Data_Quality_Level  AERONET_Instrument_Number  AERONET_Site_Name  \
# 0                lev10                         99          Cart_Site
# 1                lev10                         99          Cart_Site
# 2                lev10                         99          Cart_Site
# 3                lev10                         99          Cart_Site
# 4                lev10                         99          Cart_Site
# 5                lev10                         99          Cart_Site
# 6                lev10                         99          Cart_Site
# 7                lev10                         99          Cart_Site
# 8                lev10                         99          Cart_Site
# 9                lev10                         99          Cart_Site
# 10               lev10                         99          Cart_Site
# 11               lev10                         99          Cart_Site
#
#     Site_Latitude(Degrees)  Site_Longitude(Degrees)  Site_Elevation(m)  \
# 0                 36.60667                -97.48639              318.0
# 1                 36.60667                -97.48639              318.0
# 2                 36.60667                -97.48639              318.0
# 3                 36.60667                -97.48639              318.0
# 4                 36.60667                -97.48639              318.0
# 5                 36.60667                -97.48639              318.0
# 6                 36.60667                -97.48639              318.0
# 7                 36.60667                -97.48639              318.0
# 8                 36.60667                -97.48639              318.0
# 9                 36.60667                -97.48639              318.0
# 10                36.60667                -97.48639              318.0
# 11                36.60667                -97.48639              318.0
#
#                       geometry            datetime
# 0   POINT (-97.48639 36.60667) 2000-05-31 12:00:00
# 1   POINT (-97.48639 36.60667) 2000-06-01 12:00:00
# 2   POINT (-97.48639 36.60667) 2000-06-03 12:00:00
# 3   POINT (-97.48639 36.60667) 2000-06-04 12:00:00
# 4   POINT (-97.48639 36.60667) 2000-06-05 12:00:00
# 5   POINT (-97.48639 36.60667) 2000-06-06 12:00:00
# 6   POINT (-97.48639 36.60667) 2000-06-07 12:00:00
# 7   POINT (-97.48639 36.60667) 2000-06-08 12:00:00
# 8   POINT (-97.48639 36.60667) 2000-06-09 12:00:00
# 9   POINT (-97.48639 36.60667) 2000-06-11 12:00:00
# 10  POINT (-97.48639 36.60667) 2000-06-12 12:00:00
# 11  POINT (-97.48639 36.60667) 2000-06-13 12:00:00
#
# [12 rows x 84 columns]

# %% [markdown]
# ## Visualize results on Map screen

# %%
from folium import (
    GeoJson,
    LayerControl,
    Map
)
from folium.plugins import (
    Fullscreen
)
from IPython.display import (
    display,
    HTML
)

map: Map = Map()
layer_control = LayerControl(position="topright", collapsed=True)
fullscreen = Fullscreen()
style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}

footprints: GeoJson = GeoJson(
    geoparquet_data.dissolve(by='AERONET_Site').to_json(default=str),
    name="Stac Item footprints",
    style_function=lambda x: style,
    control=True,
)

footprints.add_to(map)
layer_control.add_to(map)
fullscreen.add_to(map)
map.fit_bounds(map.get_bounds()) # type: ignore not to important for the demo
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3016d8792cdb3e86694973193ae2d5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3016d8792cdb3e86694973193ae2d5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3016d8792cdb3e86694973193ae2d5f = L.map(
#                 &quot;map_a3016d8792cdb3e86694973193ae2d5f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50db4030f53fd536f0f580ba78eedd65 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50db4030f53fd536f0f580ba78eedd65.addTo(map_a3016d8792cdb3e86694973193ae2d5f);
#
#
#         function geo_json_2b1a9fa282985434c94ae08a9a898dc9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000ff&quot;, &quot;fillColor&quot;: &quot;#00000000&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2b1a9fa282985434c94ae08a9a898dc9_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2b1a9fa282985434c94ae08a9a898dc9 = L.geoJson(null, {
#                 onEachFeature: geo_json_2b1a9fa282985434c94ae08a9a898dc9_onEachFeature,
#
#                 style: geo_json_2b1a9fa282985434c94ae08a9a898dc9_styler,
#             ...{
# }
#         });
#
#         function geo_json_2b1a9fa282985434c94ae08a9a898dc9_add (data) {
#             geo_json_2b1a9fa282985434c94ae08a9a898dc9
#                 .addData(data);
#         }
#             geo_json_2b1a9fa282985434c94ae08a9a898dc9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-97.48639, 36.60667], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;Cart_Site&quot;, &quot;properties&quot;: {&quot;340-440_Angstrom_Exponent&quot;: 2.018901, &quot;380-500_Angstrom_Exponent&quot;: 1.853016, &quot;440-675_Angstrom_Exponent&quot;: 1.97148, &quot;440-675_Angstrom_Exponent[Polar]&quot;: -999.0, &quot;440-870_Angstrom_Exponent&quot;: 1.526441, &quot;500-870_Angstrom_Exponent&quot;: 1.455969, &quot;AERONET_Instrument_Number&quot;: 99, &quot;AERONET_Site_Name&quot;: &quot;Cart_Site&quot;, &quot;AOD_1020nm&quot;: 0.035949, &quot;AOD_1640nm&quot;: -999.0, &quot;AOD_340nm&quot;: 0.229571, &quot;AOD_380nm&quot;: 0.190454, &quot;AOD_400nm&quot;: -999.0, &quot;AOD_412nm&quot;: -999.0, &quot;AOD_440nm&quot;: 0.139392, &quot;AOD_443nm&quot;: -999.0, &quot;AOD_490nm&quot;: -999.0, &quot;AOD_500nm&quot;: 0.116071, &quot;AOD_510nm&quot;: -999.0, &quot;AOD_531nm&quot;: -999.0, &quot;AOD_532nm&quot;: -999.0, &quot;AOD_551nm&quot;: -999.0, &quot;AOD_555nm&quot;: -999.0, &quot;AOD_560nm&quot;: -999.0, &quot;AOD_620nm&quot;: -999.0, &quot;AOD_667nm&quot;: -999.0, &quot;AOD_675nm&quot;: 0.063064, &quot;AOD_681nm&quot;: -999.0, &quot;AOD_709nm&quot;: -999.0, &quot;AOD_779nm&quot;: -999.0, &quot;AOD_865nm&quot;: -999.0, &quot;AOD_870nm&quot;: 0.0524, &quot;AOD_Empty&quot;: -999.0, &quot;AOD_Empty.1&quot;: -999.0, &quot;AOD_Empty.2&quot;: -999.0, &quot;AOD_Empty.3&quot;: -999.0, &quot;AOD_Empty.4&quot;: -999.0, &quot;Data_Quality_Level&quot;: &quot;lev10&quot;, &quot;Date(dd:mm:yyyy)&quot;: &quot;31:05:2000&quot;, &quot;Day_of_Year&quot;: 152, &quot;N[340-440_Angstrom_Exponent]&quot;: 35, &quot;N[380-500_Angstrom_Exponent]&quot;: 35, &quot;N[440-675_Angstrom_Exponent[Polar]]&quot;: 0, &quot;N[440-675_Angstrom_Exponent]&quot;: 35, &quot;N[440-870_Angstrom_Exponent]&quot;: 35, &quot;N[500-870_Angstrom_Exponent]&quot;: 35, &quot;N[AOD_1020nm]&quot;: 35, &quot;N[AOD_1640nm]&quot;: 0, &quot;N[AOD_340nm]&quot;: 35, &quot;N[AOD_380nm]&quot;: 35, &quot;N[AOD_400nm]&quot;: 0, &quot;N[AOD_412nm]&quot;: 0, &quot;N[AOD_440nm]&quot;: 35, &quot;N[AOD_443nm]&quot;: 0, &quot;N[AOD_490nm]&quot;: 0, &quot;N[AOD_500nm]&quot;: 35, &quot;N[AOD_510nm]&quot;: 0, &quot;N[AOD_531nm]&quot;: 0, &quot;N[AOD_532nm]&quot;: 0, &quot;N[AOD_551nm]&quot;: 0, &quot;N[AOD_555nm]&quot;: 0, &quot;N[AOD_560nm]&quot;: 0, &quot;N[AOD_620nm]&quot;: 0, &quot;N[AOD_667nm]&quot;: 0, &quot;N[AOD_675nm]&quot;: 35, &quot;N[AOD_681nm]&quot;: 0, &quot;N[AOD_709nm]&quot;: 0, &quot;N[AOD_779nm]&quot;: 0, &quot;N[AOD_865nm]&quot;: 0, &quot;N[AOD_870nm]&quot;: 35, &quot;N[AOD_Empty]&quot;: 0, &quot;N[AOD
