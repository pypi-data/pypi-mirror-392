# %% [markdown]
# # Level 2.0 data from the "Cart_Site" for all SDA points
#
# Define a cql2-json filter for:
#
# https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?site=Cart_Site&year=2000&month=6&day=1&year2=2000&month2=6&day2=14&SDA20=1&AVG=10

# %%
from pathlib import Path
from pystac import Item

import json
import sys

out_dir: Path = Path('.')

cql2_filter = {
    "op": "and",
    "args": [
        {"op": "eq", "args": [{"property": "site"}, "Cart_Site"]},
        {"op": "eq", "args": [{"property": "data_type"}, "SDA20"]},
        {"op": "eq", "args": [{"property": "format"}, "csv"]},
        {"op": "eq", "args": [{"property": "data_format"}, "daily-average"]},
        {
            "op": "t_after",
            "args": [
                {"property": "time"},
                {"timestamp": "2000-06-01T00:00:00Z"},
            ],
        },
        {
            "op": "t_before",
            "args": [
                {"property": "time"},
                {"timestamp": "2000-06-14T23:59:59Z"},
            ],
        },
    ],
}

json.dump(cql2_filter, sys.stdout, indent=2)
# Out:
# {
#   "op": "and",
#   "args": [
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "site"
#         },
#         "Cart_Site"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "data_type"
#         },
#         "SDA20"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "format"
#         },
#         "csv"
#       ]
#     },
#     {
#       "op": "eq",
#       "args": [
#         {
#           "property": "data_format"
#         },
#         "daily-average"
#       ]
#     },
#     {
#       "op": "t_after",
#       "args": [
#         {
#           "property": "time"
#         },
#         {
#           "timestamp": "2000-06-01T00:00:00Z"
#         }
#       ]
#     },
#     {
#       "op": "t_before",
#       "args": [
#         {
#           "property": "time"
#         },
#         {
#           "timestamp": "2000-06-14T23:59:59Z"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Execute the `search` operation

# %%
from pygeofilter_aeronet import aeronet_search

item: Item = aeronet_search(
    cql2_filter=cql2_filter,
    output_dir=out_dir
)

json.dump(item.to_dict(), sys.stdout, indent=2)
# Out:
# 2025-11-14 18:08:13.741 | SUCCESS  | pygeofilter_aeronet:aeronet_search:231 - Query on https://aeronet.gsfc.nasa.gov successfully obtained data:
# 2025-11-14 18:08:13.743 | SUCCESS  | pygeofilter_aeronet:aeronet_search:239 - Data saved to to CSV file: /home/stripodi/Documents/pygeofilter/pygeofilter-aeronet/docs/samples/0d516cb3-899c-4333-bfda-3a49134c0cfc.csv
# 2025-11-14 18:08:13.750 | SUCCESS  | pygeofilter_aeronet:aeronet_search:270 - Data saved to GeoParquet file: /home/stripodi/Documents/pygeofilter/pygeofilter-aeronet/docs/samples/0d516cb3-899c-4333-bfda-3a49134c0cfc.parquet
# {
#   "type": "Feature",
#   "stac_version": "1.1.0",
#   "stac_extensions": [],
#   "id": "urn:uuid:0d516cb3-899c-4333-bfda-3a49134c0cfc",
#   "geometry": {
#     "type": "Point",
#     "coordinates": [
#       -97.48639,
#       36.60667
#     ]
#   },
#   "bbox": [
#     -97.48639,
#     36.60667,
#     -97.48639,
#     36.60667
#   ],
#   "properties": {
#     "datetime": "2025-11-14T18:08:13.780870Z"
#   },
#   "links": [
#     {
#       "rel": "related",
#       "href": "https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?site=Cart_Site&SDA20=1&if_no_html=1&AVG=20&year=2000&month=6&day=1&hour=0&year2=2000&month2=6&day2=14&hour2=23",
#       "type": "text/csv",
#       "title": "AERONET Web Service search"
#     }
#   ],
#   "assets": {
#     "csv": {
#       "href": "0d516cb3-899c-4333-bfda-3a49134c0cfc.csv",
#       "type": "text/csv",
#       "description": "Search result - CVS Format"
#     },
#     "geoparquet": {
#       "href": "0d516cb3-899c-4333-bfda-3a49134c0cfc.parquet",
#       "type": "application/vnd.apache.parquet",
#       "description": "Search result - GeoParquet Format"
#     }
#   }
# }

# %% [markdown]
# ## Visualize the results as Data Frame

# %%
from geopandas import read_parquet
from geopandas.geodataframe import GeoDataFrame

geoparquet_file: str = item.get_assets()['geoparquet'].href
geoparquet_data: GeoDataFrame = read_parquet(geoparquet_file)

geoparquet_data
# Out:
#    AERONET_Site Date_(dd:mm:yyyy) Time_(hh:mm:ss)  Day_of_Year  \
# 0     Cart_Site        31:05:2000        12:00:00          152
# 1     Cart_Site        01:06:2000        12:00:00          153
# 2     Cart_Site        04:06:2000        12:00:00          156
# 3     Cart_Site        05:06:2000        12:00:00          157
# 4     Cart_Site        06:06:2000        12:00:00          158
# 5     Cart_Site        07:06:2000        12:00:00          159
# 6     Cart_Site        08:06:2000        12:00:00          160
# 7     Cart_Site        09:06:2000        12:00:00          161
# 8     Cart_Site        11:06:2000        12:00:00          163
# 9     Cart_Site        12:06:2000        12:00:00          164
# 10    Cart_Site        13:06:2000        12:00:00          165
#
#     Total_AOD_500nm[tau_a]  Fine_Mode_AOD_500nm[tau_f]  \
# 0                 0.110159                    0.076089
# 1                 0.122092                    0.074926
# 2                 0.312680                    0.262406
# 3                 0.079892                    0.050040
# 4                 0.169686                    0.122910
# 5                 0.129509                    0.091838
# 6                 0.093119                    0.067934
# 7                 0.261388                    0.211686
# 8                 0.083175                    0.055649
# 9                 0.156430                    0.084181
# 10                0.152815                    0.069873
#
#     Coarse_Mode_AOD_500nm[tau_c]  FineModeFraction_500nm[eta]  \
# 0                       0.034070                     0.685081
# 1                       0.047167                     0.615333
# 2                       0.050274                     0.839186
# 3                       0.029852                     0.627091
# 4                       0.046777                     0.721316
# 5                       0.037671                     0.714354
# 6                       0.025185                     0.726142
# 7                       0.049702                     0.805347
# 8                       0.027526                     0.668308
# 9                       0.072250                     0.539609
# 10                      0.082942                     0.457893
#
#     2nd_Order_Reg_Fit_Error-Total_AOD_500nm[regression_dtau_a]  \
# 0                                            0.006198
# 1                                            0.005520
# 2                                            0.006488
# 3                                            0.004806
# 4                                            0.006567
# 5                                            0.006138
# 6                                            0.005370
# 7                                            0.006535
# 8                                            0.005265
# 9                                            0.004594
# 10                                           0.004385
#
#     RMSE_Fine_Mode_AOD_500nm[Dtau_f]  ...  \
# 0                           0.010284  ...
# 1                           0.009893  ...
# 2                           0.050660  ...
# 3                           0.006864  ...
# 4                           0.017211  ...
# 5                           0.011421  ...
# 6                           0.009316  ...
# 7                           0.037282  ...
# 8                           0.007773  ...
# 9                           0.012143  ...
# 10                          0.010806  ...
#
#     N[dAE/dln(wavelength)-Fine_Mode_500nm[alphap_f]]  Data_Quality_Level  \
# 0                                                 32               lev20
# 1                                                 12               lev20
# 2                                                  2               lev20
# 3                                                 55               lev20
# 4                                                 25               lev20
# 5                                                 16               lev20
# 6                                                 38               lev20
# 7                                                  7               lev20
# 8                                                  6               lev20
# 9                                                  9               lev20
# 10                                                16               lev20
#
#     AERONET_Instrument_Number  AERONET_Site_Name  Site_Latitude(Degrees)  \
# 0                          99          Cart_Site                36.60667
# 1                          99          Cart_Site                36.60667
# 2                          99          Cart_Site                36.60667
# 3                          99          Cart_Site                36.60667
# 4                          99          Cart_Site                36.60667
# 5                          99          Cart_Site                36.60667
# 6                          99          Cart_Site                36.60667
# 7                          99          Cart_Site                36.60667
# 8                          99          Cart_Site                36.60667
# 9                          99          Cart_Site                36.60667
# 10                         99          Cart_Site                36.60667
#
#     Site_Longitude(Degrees)  Site_Elevation(m)  Unnamed: 34  \
# 0                 -97.48639              318.0          NaN
# 1                 -97.48639              318.0          NaN
# 2                 -97.48639              318.0          NaN
# 3                 -97.48639              318.0          NaN
# 4                 -97.48639              318.0          NaN
# 5                 -97.48639              318.0          NaN
# 6                 -97.48639              318.0          NaN
# 7                 -97.48639              318.0          NaN
# 8                 -97.48639              318.0          NaN
# 9                 -97.48639              318.0          NaN
# 10                -97.48639              318.0          NaN
#
#                       geometry            datetime
# 0   POINT (-97.48639 36.60667) 2000-05-31 12:00:00
# 1   POINT (-97.48639 36.60667) 2000-06-01 12:00:00
# 2   POINT (-97.48639 36.60667) 2000-06-04 12:00:00
# 3   POINT (-97.48639 36.60667) 2000-06-05 12:00:00
# 4   POINT (-97.48639 36.60667) 2000-06-06 12:00:00
# 5   POINT (-97.48639 36.60667) 2000-06-07 12:00:00
# 6   POINT (-97.48639 36.60667) 2000-06-08 12:00:00
# 7   POINT (-97.48639 36.60667) 2000-06-09 12:00:00
# 8   POINT (-97.48639 36.60667) 2000-06-11 12:00:00
# 9   POINT (-97.48639 36.60667) 2000-06-12 12:00:00
# 10  POINT (-97.48639 36.60667) 2000-06-13 12:00:00
#
# [11 rows x 37 columns]

# %% [markdown]
# ## Visualize results on Map screen

# %%
from folium import (
    GeoJson,
    LayerControl,
    Map
)
from folium.plugins import (
    Fullscreen
)
from IPython.display import (
    display,
    HTML
)

map: Map = Map()
layer_control = LayerControl(position="topright", collapsed=True)
fullscreen = Fullscreen()
style = {"fillColor": "#00000000", "color": "#0000ff", "weight": 1}

footprints: GeoJson = GeoJson(
    geoparquet_data.dissolve(by='AERONET_Site').to_json(default=str),
    name="Stac Item footprints",
    style_function=lambda x: style,
    control=True,
)

footprints.add_to(map)
layer_control.add_to(map)
fullscreen.add_to(map)
map.fit_bounds(map.get_bounds()) # type: ignore not to important for the demo
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53279b42d4e212f6bc206404ee1bc4d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53279b42d4e212f6bc206404ee1bc4d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53279b42d4e212f6bc206404ee1bc4d6 = L.map(
#                 &quot;map_53279b42d4e212f6bc206404ee1bc4d6&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95979b357b68a51279c795895492b40c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95979b357b68a51279c795895492b40c.addTo(map_53279b42d4e212f6bc206404ee1bc4d6);
#
#
#         function geo_json_fa96d6dc4b1a93998cca3eddafac1b54_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000ff&quot;, &quot;fillColor&quot;: &quot;#00000000&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_fa96d6dc4b1a93998cca3eddafac1b54_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_fa96d6dc4b1a93998cca3eddafac1b54 = L.geoJson(null, {
#                 onEachFeature: geo_json_fa96d6dc4b1a93998cca3eddafac1b54_onEachFeature,
#
#                 style: geo_json_fa96d6dc4b1a93998cca3eddafac1b54_styler,
#             ...{
# }
#         });
#
#         function geo_json_fa96d6dc4b1a93998cca3eddafac1b54_add (data) {
#             geo_json_fa96d6dc4b1a93998cca3eddafac1b54
#                 .addData(data);
#         }
#             geo_json_fa96d6dc4b1a93998cca3eddafac1b54_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-97.48639, 36.60667], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;Cart_Site&quot;, &quot;properties&quot;: {&quot;2nd_Order_Reg_Fit_Error-Total_AOD_500nm[regression_dtau_a]&quot;: 0.006198, &quot;AE-Fine_Mode_500nm[alpha_f]&quot;: 2.874683, &quot;AERONET_Instrument_Number&quot;: 99, &quot;AERONET_Site_Name&quot;: &quot;Cart_Site&quot;, &quot;Angstrom_Exponent(AE)-Total_500nm[alpha]&quot;: 1.905753, &quot;Coarse_Mode_AOD_500nm[tau_c]&quot;: 0.03407, &quot;Data_Quality_Level&quot;: &quot;lev20&quot;, &quot;Date_(dd:mm:yyyy)&quot;: &quot;31:05:2000&quot;, &quot;Day_of_Year&quot;: 152, &quot;FineModeFraction_500nm[eta]&quot;: 0.685081, &quot;Fine_Mode_AOD_500nm[tau_f]&quot;: 0.076089, &quot;N[2nd_Order_Reg_Fit_Error-Total_AOD_500nm[regression_dtau_a]]&quot;: 32, &quot;N[AE-Fine_Mode_500nm[alpha_f]]&quot;: 32, &quot;N[Angstrom_Exponent(AE)-Total_500nm[alpha]]&quot;: 32, &quot;N[Coarse_Mode_AOD_500nm[tau_c]]&quot;: 32, &quot;N[FineModeFraction_500nm[eta]]&quot;: 32, &quot;N[Fine_Mode_AOD_500nm[tau_f]]&quot;: 32, &quot;N[RMSE_Coarse_Mode_AOD_500nm[Dtau_c]]&quot;: 32, &quot;N[RMSE_FineModeFraction_500nm[Deta]]&quot;: 32, &quot;N[RMSE_Fine_Mode_AOD_500nm[Dtau_f]]&quot;: 32, &quot;N[Total_AOD_500nm[tau_a]]&quot;: 32, &quot;N[dAE/dln(wavelength)-Fine_Mode_500nm[alphap_f]]&quot;: 32, &quot;N[dAE/dln(wavelength)-Total_500nm[alphap]]&quot;: 32, &quot;RMSE_Coarse_Mode_AOD_500nm[Dtau_c]&quot;: 0.008681, &quot;RMSE_FineModeFraction_500nm[Deta]&quot;: 0.07538, &quot;RMSE_Fine_Mode_AOD_500nm[Dtau_f]&quot;: 0.010284, &quot;Site_Elevation(m)&quot;: 318.0, &quot;Site_Latitude(Degrees)&quot;: 36.60667, &quot;Site_Longitude(Degrees)&quot;: -97.48639, &quot;Time_(hh:mm:ss)&quot;: &quot;12:00:00&quot;, &quot;Total_AOD_500nm[tau_a]&quot;: 0.110159, &quot;Unnamed: 34&quot;: null, &quot;dAE/dln(wavelength)-Fine_Mode_500nm[alphap_f]&quot;: 0.926935, &quot;dAE/dln(wavelength)-Total_500nm[alphap]&quot;: -1.387985, &quot;datetime&quot;: &quot;2000-05-31 12:00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_fa96d6dc4b1a93998cca3eddafac1b54.addTo(map_53279b42d4e212f6bc206404ee1bc4d6);
#
#
#             var layer_control_bce957113b2fd10de80ce49c7343be1f_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_95979b357b68a51279c795895492b40c,
#                 },
#                 overlays :  {
#                     &quot;Stac Item footprints&quot; : geo_json_fa96d6dc4b1a93998cca3eddafac1b54,
#                 },
#             };
#             le
